# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
data = pd.read_csv("DOGE-USD.csv")
data.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume
# 0  2022-04-26  0.157777  0.165278  0.137424  0.137767   0.137767  4529010503
# 1  2022-04-27  0.137847  0.145405  0.136272  0.139700   0.139700  1765370972
# 2  2022-04-28  0.139691  0.142618  0.136058  0.137363   0.137363  1105137506
# 3  2022-04-29  0.137376  0.144643  0.134099  0.135027   0.135027  1555397213
# 4  2022-04-30  0.135033  0.136528  0.126239  0.127557   0.127557   916612071

# %%
data.dropna()
# Out:
#            Date      Open      High       Low     Close  Adj Close      Volume
# 0    2022-04-26  0.157777  0.165278  0.137424  0.137767   0.137767  4529010503
# 1    2022-04-27  0.137847  0.145405  0.136272  0.139700   0.139700  1765370972
# 2    2022-04-28  0.139691  0.142618  0.136058  0.137363   0.137363  1105137506
# 3    2022-04-29  0.137376  0.144643  0.134099  0.135027   0.135027  1555397213
# 4    2022-04-30  0.135033  0.136528  0.126239  0.127557   0.127557   916612071
# ..          ...       ...       ...       ...       ...        ...         ...
# 361  2023-04-22  0.078482  0.080919  0.078313  0.080375   0.080375   396888464
# 362  2023-04-23  0.080380  0.080628  0.077437  0.078820   0.078820   365182428
# 363  2023-04-24  0.078819  0.079973  0.077569  0.078784   0.078784   392854009
# 364  2023-04-25  0.078783  0.079926  0.077756  0.079847   0.079847   343833135
# 365  2023-04-26  0.079744  0.083372  0.079693  0.082531   0.082531   470867008
#
# [366 rows x 7 columns]

# %%
plt.figure(figsize=(10, 4))
plt.title('DogeCoin Price INR')
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data['Close'])
plt.show()

# %%
x = data[["Open", "High", "Low", "Volume"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y,test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(xtrain, ytrain)
print(lr.score(xtest,ytest))
# Out:
# 0.9920787887900934
